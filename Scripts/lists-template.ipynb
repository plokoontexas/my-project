# %% [markdown]
# ## Working with lists

# %%
# declare an empty string
bob = ''

# declare a list
boygenius = []
beatles = []

# %% [markdown]
# ### What kind of variable is this?

# %%
print(type(bob))
print(type(boygenius))
# Out:
# <class 'str'>
# <class 'list'>

# %% [markdown]
# ### Populate and print a list

# %%
boygenius = ["Lucy", "Julien", "Pheobe"]

beatles = ["John", "Paul", "George", "Ringo", "Stuart"]

#Print the whole list 

print(beatles)
# Out:
# ['John', 'Paul', 'George', 'Ringo', 'Stuart']

# %% [markdown]
# ### Calculate and print the length of a list

# %%
# calculate number of beatles
number_of_beatles = len(beatles)
# print number of beatles
print(f"There were {number_of_beatles} people in the Beatles")
# Out:
# There were 5 people in the Beatles

# %% [markdown]
# ### Print an item in a list
#
#    _see PowerPoint slides_

# %%
# remind ourseles of the list

print(beatles)

# print the first beatle
print(beatles[0])
# print the last Beatle
print(beatles[4])
print(beatles[-1])
# Out:
# ['John', 'Paul', 'George', 'Ringo', 'Stuart']
# John
# Stuart

# %% [markdown]
# ### Remove an item from a list

# %%
# Remove the last item in the list (bye, Stuart)
beatles.pop()
# What happened to the Beatles?

# %% [markdown]
# ### Make a new list

# %%
# make a list called 'stones' with the Rolling Stones (Mick, Ron, and Keith)
stones = ["Mick", "Ron", "Keith"]

# %% [markdown]
# ### Add two lists

# %%
# add two lists together
print (f"the two groups seperately: {beatles}, {stones}")

supergroup = beatles + stones

# print our new list

print (supergroup)

print(f"{len(supergroup)} members in our new band {supergroup}")
# Out:
# the two groups seperately: ['John', 'Paul', 'George', 'Ringo', 'Stuart'], ['Mick', 'Ron', 'Keith']
# ['John', 'Paul', 'George', 'Ringo', 'Stuart', 'Mick', 'Ron', 'Keith']
# 8 members in our new band ['John', 'Paul', 'George', 'Ringo', 'Stuart', 'Mick', 'Ron', 'Keith']

# %% [markdown]
# ### Make some new lists

# %%
# start fresh with new groups
jackson5 = ['jackie', 'tito', 'jermaine', 'marlon', 'michael']
destiny  = ['beyonce', 'kelly', 'michelle']
boygenius = ["Lucy", "Julien", "Pheobe"]

#remove micheal 
jackson5.pop()

# make a supergroup
# Out:
# 'michael'

# %% [markdown]
# ### Growing a list with `extend()`

# %%
# print our lists
print(f"Jackson 5: {jackson5}")
print(f"Destinys Child: {destiny}")
# use extend() to add Destiny's Child to the Jackson 5
# Out:
# Jackson 5: ['jackie', 'tito', 'jermaine', 'marlon']
# Destinys Child: ['beyonce', 'kelly', 'michelle']

# %%
# extend() modifies a list in place, it doesn't return a value (i.e., a new list)

jackson5.extend(destiny)

print(f"Heres the extended Jackson 5: {jackson5}")
# Out:
# Heres the extended Jackson 5: ['jackie', 'tito', 'jermaine', 'marlon', 'beyonce', 'kelly', 'michelle']

# %%
# use "+" if you want to create a new list

# %% [markdown]
# ### Growing a list with `append()`

# %%
# use `append()` to add lists in a different way 

num = [1,2,3]
let = ["a", "b","c"]
print(f"our lists : {num, let}")


# append let onto num 
num.append(let)

# What did append do?
 
print(num)
# Out:
# our lists : ([1, 2, 3], ['a', 'b', 'c'])
# [1, 2, 3, ['a', 'b', 'c']]

# %%
# How long is this list?
len(num)
# print the letters
print(num [-1])
# Out:
# ['a', 'b', 'c']

# %%
#find and print b 
print(type(num[-1]))

print(num[-1][1])
# Out:
# <class 'list'>
# b
